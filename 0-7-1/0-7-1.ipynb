# %%
import numpy as np
import re
import string
import pprint

file = open('C:/Users/Niels/source/repos/aoc-2020/0-7-1/input.txt').readlines()
file = [l.strip() for l in file]

bag_dict = {}

for line in file:
    l_spl = line.replace('bags', '').replace('bag', '').split(' contain ')
    key = l_spl[0].strip()
    bag_dict[key] = {}
    
    expands = l_spl[1].replace('.', '').split(', ')
    expands = [x.strip() for x in expands]
    if expands[0] == 'no other':
        continue
    
    for exp in expands:
        exspl = exp.split(' ', 1)
        bag_dict[key][exspl[1]] = exspl[0]



bags = []
def expand_up(current):
    up = []
    count = 0

    for key in bag_dict:
        if any(c in bag_dict[key].keys() for c in current):
            bags.append(key)
            up.append(key)

    if len(up) != 0:
        expand_up(up)

expand_up(['shiny gold'])

print(len(set(bags)))
# Out:
# , 'drab bronze': '2', 'shiny coral': '2'},
#  'muted teal': {'light tomato': '5', 'plaid turquoise': '1'},
#  'muted tomato': {'faded orange': '1'},
#  'muted turquoise': {'mirrored lime': '1', 'shiny chartreuse': '5'},
#  'muted violet': {'striped turquoise': '3', 'vibrant lime': '3'},
#  'muted white': {'drab gray': '5', 'faded white': '5', 'vibrant beige': '3'},
#  'muted yellow': {'dim aqua': '2', 'vibrant indigo': '4'},
#  'pale aqua': {'dark gold': '2',
#                'faded beige': '3',
#                'posh gray': '2',
#                'vibrant cyan': '1'},
#  'pale beige': {'posh tomato': '2', 'vibrant orange': '4'},
#  'pale black': {'drab green': '2',
#                 'plaid teal': '4',
#                 'posh silver': '3',
#                 'wavy olive': '4'},
#  'pale blue': {'dim brown': '1',
#                'drab magenta': '5',
#                'posh green': '2',
#                'shiny lavender': '5'},
#  'pale bronze': {'dotted lime': '2', 'plaid teal': '3', 'posh aqua': '2'},
#  'pale brown': {'dark blue': '2', 'light salmon': '1', 'striped yellow': '4'},
#  'pale chartreuse': {'dim cyan': '4', 'pale lime': '1'},
#  'pale coral': {'dotted turquoise': '2',
#                 'striped gray': '5',
#                 'striped violet': '4',
#                 'wavy lavender': '4'},
#  'pale crimson': {'drab silver': '5', 'striped crimson': '2'},
#  'pale cyan': {'dark blue': '5', 'dull blue': '5'},
#  'pale fuchsia': {'bright chartreuse': '4', 'dull yellow': '5'},
#  'pale gold': {'dark purple': '3'},
#  'pale gray': {'drab gray': '1'},
#  'pale green': {'mirrored aqua': '1',
#                 'mirrored indigo': '2',
#                 'vibrant red': '4'},
#  'pale indigo': {'clear magenta': '5',
#                  'drab turquoise': '3',
#                  'light violet': '5',
#                  'striped blue': '1'},
#  'pale lavender': {'dim plum': '1', 'posh salmon': '1', 'vibrant lime': '4'},
#  'pale lime': {'dull blue': '3'},
#  'pale magenta': {'dark maroon': '5', 'mirrored aqua': '3'},
#  'pale maroon': {'mirrored magenta': '2', 'pale crimson': '1'},
#  'pale olive': {'dull violet': '2',
#                 'light red': '4',
#                 'shiny maroon': '5',
#                 'wavy cyan': '2'},
#  'pale orange': {'plaid tomato': '2'},
#  'pale plum': {'dim gold': '1',
#                'pale lime': '5',
#                'plaid gold': '3',
#                'wavy olive': '3'},
#  'pale purple': {'faded beige': '4', 'shiny lavender': '5', 'wavy tan': '1'},
#  'pale red': {'bright cyan': '1', 'mirrored magenta': '2', 'vibrant lime': '2'},
#  'pale salmon': {'faded black': '2', 'pale turquoise': '3', 'wavy green': '5'},
#  'pale silver': {'drab olive': '2', 'wavy red': '5'},
#  'pale tan': {'clear blue': '2',
#               'dark bronze': '3',
#               'plaid coral': '2',
#               'vibrant magenta': '3'},
#  'pale teal': {'clear violet': '5',
#                'light lavender': '5',
#                'posh lavender': '4'},
#  'pale tomato': {'dark tomato': '2'},
#  'pale turquoise': {'dotted purple': '5', 'pale blue': '2'},
#  'pale violet': {'clear salmon': '1', 'posh maroon': '5', 'posh plum': '4'},
#  'pale white': {'clear gray': '2',
#                 'pale purple': '3',
#                 'shiny lavender': '2',
#                 'striped yellow': '5'},
#  'pale yellow': {'striped cyan': '4', 'wavy salmon': '1', 'wavy tan': '2'},
#  'plaid aqua': {'mirrored green': '3'},
#  'plaid beige': {'striped black': '1', 'striped blue': '4', 'wavy purple': '2'},
#  'plaid black': {'bright maroon': '5',
#                  'dim olive': '3',
#                  'muted lavender': '4',
#                  'muted violet': '5'},
#  'plaid blue': {'mirrored indigo': '3'},
#  'plaid bronze': {'dull silver': '2'},
#  'plaid brown': {'faded black': '3', 'faded white': '5', 'wavy violet': '5'},
#  'plaid chartreuse': {'clear blue': '3',
#                       'dull aqua': '1',
#                       'vibrant beige': '2',
#                       'wavy fuchsia': '2'},
#  'plaid coral': {'striped black': '1'},
#  'plaid crimson': {'plaid beige': '1'},
#  'plaid cyan': {'vibrant turquoise': '3'},
#  'plaid fuchsia': {'posh aqua': '4', 'posh salmon': '3', 'wavy magenta': '3'},
#  'plaid gold': {'wavy magenta': '4'},
#  'plaid gray': {'faded silver': '3',
#                 'mirrored white': '2',
#                 'plaid turquoise': '1',
#                 'shiny brown': '1'},
#  'plaid green': {'dotted blue': '1'},
#  'plaid indigo': {'bright cyan': '5'},
#  'plaid lavender': {'plaid orange': '3', 'striped plum': '3'},
#  'plaid lime': {'clear black': '4', 'dotted coral': '3', 'dull brown': '1'},
#  'plaid magenta': {'wavy cyan': '4'},
#  'plaid maroon': {'clear lime': '4', 'muted violet': '1', 'vibrant teal': '4'},
#  'plaid olive': {'dull purple': '4',
#                  'dull yellow': '4',
#                  'faded silver': '5',
#                  'plaid salmon': '1'},
#  'plaid orange': {'light tomato': '1', 'shiny tomato': '1'},
#  'plaid plum': {},
#  'plaid purple': {'dark bronze': '4', 'drab aqua': '1', 'vibrant olive': '1'},
#  'plaid red': {'vibrant aqua': '4'},
#  'plaid salmon': {'dark tomato': '3', 'light maroon': '5'},
#  'plaid silver': {'clear magenta': '3',
#                   'faded indigo': '5',
#                   'light salmon': '4'},
#  'plaid tan': {'dull purple': '5',
#                'posh turquoise': '2',
#                'vibrant bronze': '3'},
#  'plaid teal': {'dark silver': '1',
#                 'dim cyan': '4',
#                 'drab lavender': '4',
#                 'muted black': '2'},
#  'plaid tomato': {'plaid plum': '3',
#                   'posh aqua': '2',
#                   'striped turquoise': '2'},
#  'plaid turquoise': {'dotted salmon': '3', 'posh aqua': '2', 'wavy plum': '3'},
#  'plaid violet': {'pale brown': '4', 'vibrant violet': '2'},
#  'plaid white': {'drab aqua': '5', 'light coral': '3', 'striped orange': '3'},
#  'plaid yellow': {'drab fuchsia': '5', 'faded brown': '1', 'faded gold': '1'},
#  'posh aqua': {'posh magenta': '2'},
#  'posh beige': {'light violet': '4', 'pale lime': '4'},
#  'posh black': {'pale violet': '4', 'plaid violet': '5', 'posh magenta': '2'},
#  'posh blue': {'clear tan': '2',
#                'light tomato': '5',
#                'vibrant salmon': '4',
#                'wavy maroon': '1'},
#  'posh bronze': {'dim orange': '2', 'posh lavender': '1'},
#  'posh brown': {'shiny cyan': '4'},
#  'posh chartreuse': {'dim violet': '1',
#                      'faded chartreuse': '4',
#                      'light blue': '5',
#                      'shiny black': '4'},
#  'posh coral': {'dim lavender': '2', 'dotted salmon': '3', 'wavy purple': '4'},
#  'posh crimson': {'dim bronze': '4', 'wavy plum': '1'},
#  'posh cyan': {'faded chartreuse': '5', 'pale orange': '5'},
#  'posh fuchsia': {'drab brown': '1', 'pale orange': '2', 'posh coral': '4'},
#  'posh gold': {'dim crimson': '4', 'dull black': '2', 'plaid beige': '3'},
#  'posh gray': {'mirrored gold': '4', 'muted aqua': '3', 'striped black': '4'},
#  'posh green': {'light aqua': '2', 'posh magenta': '5', 'wavy purple': '3'},
#  'posh indigo': {'shiny salmon': '1'},
#  'posh lavender': {'dim yellow': '1', 'light teal': '4', 'wavy turquoise': '4'},
#  'posh lime': {'dim lavender': '1'},
#  'posh magenta': {'dull blue': '2',
#                   'light aqua': '5',
#                   'plaid plum': '4',
#                   'vibrant lime': '2'},
#  'posh maroon': {'dark blue': '3', 'dull olive': '4'},
#  'posh olive': {'dark magenta': '4',
#                 'faded chartreuse': '4',
#                 'plaid tomato': '5'},
#  'posh orange': {'clear black': '3',
#                  'faded maroon': '1',
#                  'light silver': '3',
#                  'wavy red': '5'},
#  'posh plum': {'bright red': '2', 'shiny maroon': '3'},
#  'posh purple': {'dark tan': '5', 'faded tomato': '1', 'wavy salmon': '2'},
#  'posh red': {'muted tan': '3'},
#  'posh salmon': {'bright coral': '5',
#                  'dull black': '1',
#                  'muted aqua': '3',
#                  'muted fuchsia': '4'},
#  'posh silver': {},
#  'posh tan': {'dotted purple': '1', 'vibrant gold': '5'},
#  'posh teal': {'dim cyan': '5',
#                'mirrored indigo': '4',
#                'plaid silver': '4',
#                'striped purple': '3'},
#  'posh tomato': {'dark purple': '3',
#                  'dim olive': '3',
#                  'dotted white': '2',
#                  'mirrored cyan': '3'},
#  'posh turquoise': {'dotted black': '4',
#                     'drab bronze': '3',
#                     'muted indigo': '2',
#                     'striped white': '2'},
#  'posh violet': {'dark green': '2',
#                  'light blue': '3',
#                  'pale chartreuse': '5',
#                  'vibrant indigo': '5'},
#  'posh white': {'dark cyan': '1',
#                 'dark magenta': '1',
#                 'pale plum': '2',
#                 'striped teal': '2'},
#  'posh yellow': {'dim aqua': '4', 'shiny brown': '1', 'striped orange': '3'},
#  'shiny aqua': {'dark maroon': '2', 'faded silver': '4'},
#  'shiny beige': {'light blue': '5',
#                  'light salmon': '2',
#                  'vibrant plum': '5',
#                  'wavy tan': '3'},
#  'shiny black': {'light maroon': '5',
#                  'mirrored indigo': '2',
#                  'vibrant cyan': '4'},
#  'shiny blue': {'drab turquoise': '4'},
#  'shiny bronze': {'bright indigo': '5',
#                   'shiny purple': '1',
#                   'striped indigo': '5',
#                   'striped yellow': '5'},
#  'shiny brown': {'muted aqua': '5',
#                  'plaid plum': '5',
#                  'posh silver': '1',
#                  'vibrant lime': '3'},
#  'shiny chartreuse': {'bright brown': '3',
#                       'clear black': '1',
#                       'dim cyan': '2',
#                       'shiny brown': '4'},
#  'shiny coral': {'muted lavender': '1',
#                  'muted purple': '5',
#                  'striped orange': '1'},
#  'shiny crimson': {'dim fuchsia': '5', 'posh salmon': '4'},
#  'shiny cyan': {'clear beige': '5', 'wavy cyan': '1'},
#  'shiny fuchsia': {'striped coral': '2'},
#  'shiny gold': {'dull white': '2', 'posh green': '3'},
#  'shiny gray': {'shiny black': '2', 'striped white': '5'},
#  'shiny green': {'dim red': '4', 'dotted plum': '2', 'vibrant blue': '3'},
#  'shiny indigo': {'posh beige': '5'},
#  'shiny lavender': {'dim cyan': '1',
#                     'dim olive': '2',
#                     'shiny plum': '1',
#                     'vibrant aqua': '3'},
#  'shiny lime': {'dotted blue': '4', 'light coral': '5'},
#  'shiny magenta': {'dull aqua': '1', 'plaid blue': '5', 'shiny aqua': '5'},
#  'shiny maroon': {'dark purple': '5', 'faded silver': '5', 'pale gold': '5'},
#  'shiny olive': {'bright purple': '1', 'dark plum': '2', 'pale red': '5'},
#  'shiny orange': {'clear green': '1', 'dull purple': '3'},
#  'shiny plum': {},
#  'shiny purple': {'striped yellow': '2', 'wavy lavender': '3'},
#  'shiny red': {'dim fuchsia': '3',
#                'posh violet': '3',
#                'shiny silver': '3',
#                'wavy gold': '3'},
#  'shiny salmon': {'bright silver': '1',
#                   'faded gray': '1',
#                   'muted lime': '1',
#                   'vibrant chartreuse': '5'},
#  'shiny silver': {'light blue': '4', 'muted gold': '5'},
#  'shiny tan': {'dotted turquoise': '4',
#                'pale violet': '4',
#                'plaid salmon': '3',
#                'striped gold': '1'},
#  'shiny teal': {'mirrored tomato': '3', 'plaid coral': '3', 'shiny coral': '2'},
#  'shiny tomato': {'shiny plum': '4'},
#  'shiny turquoise': {'dull olive': '4',
#                      'pale purple': '1',
#                      'striped bronze': '5'},
#  'shiny violet': {'bright maroon': '2',
#                   'mirrored black': '3',
#                   'vibrant gold': '2'},
#  'shiny white': {'dark indigo': '5', 'dim aqua': '2', 'vibrant aqua': '5'},
#  'shiny yellow': {'clear beige': '1',
#                   'shiny chartreuse': '5',
#                   'wavy green': '2'},
#  'striped aqua': {'mirrored purple': '4'},
#  'striped beige': {'drab lavender': '5'},
#  'striped black': {'dark maroon': '1', 'dull blue': '2', 'vibrant aqua': '1'},
#  'striped blue': {'dark tomato': '4', 'dim aqua': '2', 'dull olive': '1'},
#  'striped bronze': {'bright magenta': '5'},
#  'striped brown': {'clear gray': '5', 'wavy salmon': '3'},
#  'striped chartreuse': {'posh gold': '2', 'striped lime': '1'},
#  'striped coral': {'dark brown': '1',
#                    'posh green': '1',
#                    'striped turquoise': '3'},
#  'striped crimson': {'shiny brown': '3'},
#  'striped cyan': {'dark brown': '4', 'striped gray': '3'},
#  'striped fuchsia': {'clear beige': '4',
#                      'shiny crimson': '4',
#                      'shiny lavender': '4',
#                      'striped red': '1'},
#  'striped gold': {'dark coral': '1',
#                   'dull gold': '3',
#                   'light purple': '3',
#                   'wavy silver': '2'},
#  'striped gray': {'dark tomato': '4'},
#  'striped green': {'clear tomato': '4',
#                    'pale green': '1',
#                    'striped red': '1',
#                    'striped tomato': '5'},
#  'striped indigo': {'drab brown': '2'},
#  'striped lavender': {'dull brown': '2',
#                       'dull gold': '5',
#                       'vibrant aqua': '1',
#                       'vibrant lavender': '4'},
#  'striped lime': {'dull blue': '3',
#                   'muted aqua': '2',
#                   'posh silver': '3',
#                   'shiny lavender': '2'},
#  'striped magenta': {'light maroon': '4'},
#  'striped maroon': {'faded blue': '5'},
#  'striped olive': {'dim tomato': '4'},
#  'striped orange': {},
#  'striped plum': {'pale violet': '3'},
#  'striped purple': {'vibrant beige': '5', 'vibrant bronze': '3'},
#  'striped red': {'plaid green': '3'},
#  'striped salmon': {'striped lime': '1'},
#  'striped silver': {'shiny indigo': '3'},
#  'striped tan': {'dark violet': '2', 'muted indigo': '2'},
#  'striped teal': {'vibrant cyan': '2'},
#  'striped tomato': {'dotted violet': '1',
#                     'light beige': '1',
#                     'vibrant violet': '3'},
#  'striped turquoise': {'drab magenta': '5',
#                        'light aqua': '2',
#                        'shiny lavender': '2'},
#  'striped violet': {'clear violet': '2',
#                     'dark lime': '5',
#                     'striped yellow': '1'},
#  'striped white': {'light brown': '2', 'light coral': '1'},
#  'striped yellow': {'dim tomato': '4'},
#  'vibrant aqua': {'faded silver': '1'},
#  'vibrant beige': {'bright lavender': '3',
#                    'drab gray': '3',
#                    'dull white': '4',
#                    'shiny gold': '4'},
#  'vibrant black': {'dim violet': '5'},
#  'vibrant blue': {'shiny brown': '1', 'shiny crimson': '5'},
#  'vibrant bronze': {'shiny aqua': '4'},
#  'vibrant brown': {'light blue': '4', 'light gold': '5', 'light purple': '3'},
#  'vibrant chartreuse': {'clear teal': '1',
#                         'dull indigo': '2',
#                         'mirrored tan': '5',
#                         'vibrant blue': '4'},
#  'vibrant coral': {'bright green': '2'},
#  'vibrant crimson': {'dark beige': '5',
#                      'drab lavender': '5',
#                      'dull maroon': '5'},
#  'vibrant cyan': {'dim fuchsia': '4', 'dull blue': '5'},
#  'vibrant fuchsia': {'light maroon': '1', 'muted aqua': '4'},
#  'vibrant gold': {'dark violet': '4', 'faded crimson': '1'},
#  'vibrant gray': {'mirrored silver': '5',
#                   'pale brown': '3',
#                   'shiny tomato': '2',
#                   'striped tomato': '3'},
#  'vibrant green': {'dotted violet': '4',
#                    'plaid blue': '5',
#                    'shiny maroon': '3'},
#  'vibrant indigo': {'clear lime': '3', 'dark silver': '5', 'dim gray': '1'},
#  'vibrant lavender': {'clear black': '4',
#                       'dark tomato': '1',
#                       'dim fuchsia': '2',
#                       'vibrant lime': '3'},
#  'vibrant lime': {},
#  'vibrant magenta': {'light tan': '2',
#                      'muted yellow': '2',
#                      'shiny brown': '5',
#                      'striped yellow': '5'},
#  'vibrant maroon': {'plaid plum': '3'},
#  'vibrant olive': {'bright white': '3',
#                    'mirrored magenta': '5',
#                    'plaid salmon': '1'},
#  'vibrant orange': {'light brown': '5', 'posh silver': '4'},
#  'vibrant plum': {'mirrored indigo': '2',
#                   'muted violet': '2',
#                   'pale chartreuse': '4'},
#  'vibrant purple': {'dark silver': '5', 'striped gold': '2'},
#  'vibrant red': {'dark blue': '5',
#                  'faded green': '3',
#                  'light aqua': '4',
#                  'striped orange': '4'},
#  'vibrant salmon': {'faded lime': '3'},
#  'vibrant silver': {'plaid gold': '2', 'striped blue': '4'},
#  'vibrant tan': {'dim tomato': '4',
#                  'pale olive': '5',
#                  'posh aqua': '2',
#                  'vibrant violet': '4'},
#  'vibrant teal': {'dark silver': '1', 'pale white': '2', 'vibrant red': '5'},
#  'vibrant tomato': {'dim turquoise': '5',
#                     'pale blue': '1',
#                     'plaid red': '3',
#                     'striped brown': '2'},
#  'vibrant turquoise': {'striped teal': '4',
#                        'striped white': '5',
#                        'vibrant blue': '1'},
#  'vibrant violet': {'bright red': '5', 'shiny brown': '3', 'vibrant cyan': '3'},
#  'vibrant white': {'muted aqua': '5', 'shiny turquoise': '5'},
#  'vibrant yellow': {'dotted beige': '2',
#                     'mirrored teal': '4',
#                     'shiny lime': '2',
#                     'striped purple': '1'},
#  'wavy aqua': {'bright fuchsia': '1', 'dim maroon': '3', 'light tan': '4'},
#  'wavy beige': {'dull green': '4',
#                 'muted purple': '1',
#                 'striped turquoise': '4',
#                 'wavy plum': '2'},
#  'wavy black': {'vibrant bronze': '2', 'wavy red': '5'},
#  'wavy blue': {'clear red': '4'},
#  'wavy bronze': {'dim green': '3', 'dotted tan': '5', 'muted indigo': '2'},
#  'wavy brown': {'dotted salmon': '3'},
#  'wavy chartreuse': {'bright fuchsia': '4',
#                      'dull aqua': '2',
#                      'vibrant violet': '3'},
#  'wavy coral': {'bright coral': '1', 'bright tan': '3', 'dull gold': '4'},
#  'wavy crimson': {'dull maroon': '4',
#                   'plaid plum': '1',
#                   'posh coral': '4',
#                   'wavy lime': '1'},
#  'wavy cyan': {'posh coral': '1', 'shiny black': '2'},
#  'wavy fuchsia': {'dark maroon': '3', 'muted aqua': '5', 'striped coral': '5'},
#  'wavy gold': {'drab aqua': '1'},
#  'wavy gray': {'striped bronze': '2'},
#  'wavy green': {'drab gray': '5',
#                 'muted blue': '2',
#                 'plaid plum': '5',
#                 'posh magenta': '2'},
#  'wavy indigo': {'bright brown': '3',
#                  'clear cyan': '1',
#                  'mirrored orange': '4',
#                  'pale cyan': '3'},
#  'wavy lavender': {'dark white': '5',
#                    'dotted salmon': '1',
#                    'dull silver': '2',
#                    'muted blue': '3'},
#  'wavy lime': {'dull silver': '4'},
#  'wavy magenta': {'posh green': '1', 'vibrant aqua': '4', 'vibrant cyan': '1'},
#  'wavy maroon': {'muted gold': '5', 'posh yellow': '4'},
#  'wavy olive': {'dim lavender': '2', 'dull beige': '3', 'striped gold': '1'},
#  'wavy orange': {'dull tomato': '4',
#                  'mirrored indigo': '3',
#                  'striped lime': '1',
#                  'vibrant plum': '2'},
#  'wavy plum': {'drab lavender': '5', 'plaid plum': '3'},
#  'wavy purple': {'dull blue': '5',
#                  'light aqua': '2',
#                  'striped lime': '3',
#                  'striped orange': '3'},
#  'wavy red': {'vibrant blue': '5'},
#  'wavy salmon': {'dark turquoise': '4',
#                  'dim olive': '5',
#                  'drab teal': '5',
#                  'posh magenta': '3'},
#  'wavy silver': {'pale cyan': '5'},
#  'wavy tan': {'dim brown': '3'},
#  'wavy teal': {'dull cyan': '2', 'shiny lime': '5'},
#  'wavy tomato': {'striped teal': '4'},
#  'wavy turquoise': {'bright maroon': '3', 'dim crimson': '4', 'pale cyan': '3'},
#  'wavy violet': {'drab gray': '4'},
#  'wavy white': {'bright purple': '3', 'faded crimson': '1', 'posh lime': '2'},
#  'wavy yellow': {'dotted salmon': '2'}}
# 128

# %%
def count_recursively(current):
    if len(bag_dict[current]) == 0:
        return 0
    count = 0
    for subbags in bag_dict[current]:
        count += int(bag_dict[current][subbags])
        count += int(bag_dict[current][subbags]) * count_recursively(subbags)
    return count

print(count_recursively('shiny gold'))
# Out:
# 20189
